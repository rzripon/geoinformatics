# %% [markdown]
# <h1>Exercise 5<h1>

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_alt_vs_dtmalt = pd.read_csv("DTMaltitudeValue.csv")

df_alt_vs_dtmalt.head()
# Out:
#    fid  station_id  altitude  latitude  longitude  t_total_prec_value  \
# 0    1         216       298   51.1143     7.8807               273.7
# 1    2         389       436   51.0148     8.4318               175.6
# 2    3         390       610   50.9837     8.3683               179.2
# 3    4         613       206   51.5677     9.2324               130.1
# 4    5         644       150   51.7049     9.1738               115.0
#
#                       name                state    rvalue_1
# 0  Attendorn-Neulisternohl  Nordrhein-Westfalen  298.100006
# 1    Berleburg, Bad-Arfeld  Nordrhein-Westfalen  433.500000
# 2   Berleburg, Bad-Stünzel  Nordrhein-Westfalen  612.200012
# 3             Borgentreich  Nordrhein-Westfalen  205.000000
# 4                   Brakel  Nordrhein-Westfalen  150.199997

# %%
df = pd.DataFrame(df_alt_vs_dtmalt)
df
# Out:
#     fid  station_id  altitude  latitude  longitude  t_total_prec_value  \
# 0     1         216       298   51.1143     7.8807               273.7
# 1     2         389       436   51.0148     8.4318               175.6
# 2     3         390       610   50.9837     8.3683               179.2
# 3     4         613       206   51.5677     9.2324               130.1
# 4     5         644       150   51.7049     9.1738               115.0
# 5     6         796       412   50.7556     8.1257               168.0
# 6     7         934        88   51.7835     8.5658               116.8
# 7     8        1300       351   51.2540     8.1565               201.8
# 8     9        2483       839   51.1803     8.4891               222.2
# 9    10        2947       286   51.1333     8.0348               291.1
# 10   11        3028       157   51.7854     8.8388               179.3
# 11   12        3031        92   51.6336     8.3945               157.1
# ...

# %%
df.plot.bar(x='station_id', y=['altitude','rvalue_1'],figsize=(20, 10), xlabel='STATIONS', ylabel='ALTITUDES' , title='ALTITUDES from 2 different sources')
plt.savefig("Exc5_ALTITUDES_from_2different_sources.png", bbox_inches='tight')
;
# Out:
# ''
